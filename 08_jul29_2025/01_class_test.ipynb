# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import random
from dataclasses import dataclass
from typing import List, Tuple
import matplotlib.animation as animation

from settings_e import *

# %%
ca_model, grid = run_simulation()
# Out:
# Time (s) | Nucleated | Grown | RX Fraction
# ---------------------------------------------
#     0.01 |         0 |      0 |       0.000
#     1.01 |         0 |      0 |       0.000
#     2.01 |         0 |      0 |       0.000
#     3.01 |         0 |      0 |       0.000
#     4.01 |         0 |      0 |       0.000
#     5.01 |         0 |      0 |       0.000
#     6.01 |         0 |      0 |       0.000
#     7.01 |         0 |      0 |       0.000
#     8.01 |         0 |      0 |       0.000
#     9.01 |         0 |      0 |       0.000
#    10.01 |         0 |      0 |       0.000
#    11.01 |         0 |      0 |       0.000
#    12.01 |         0 |      0 |       0.000
#    13.01 |         0 |      0 |       0.000
#    14.01 |         0 |      0 |       0.000
#    15.01 |         0 |      0 |       0.000
#    16.01 |         0 |      0 |       0.000
#    17.01 |         0 |      0 |       0.000
#    18.01 |         0 |      0 |       0.000
#    19.01 |         0 |      0 |       0.000
#
# Final number of grains: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ca_model, grid = run_simulation()
#
# File d:\ca_implement\settings_e.py:346, in run_simulation()
#     344 n_grains = len(np.unique(orientation_final)) - 1  # Subtract deformed phase
#     345 print(f"\nFinal number of grains: {n_grains}")
# --> 346 print(f"Average grain area: {(nx*ny)/n_grains:.1f} cells")
#     348 plt.show()
#     350 return ca, grid
#
# ZeroDivisionError: division by zero
